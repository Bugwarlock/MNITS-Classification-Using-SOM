# %%
import matplotlib.pyplot as plt
import numpy as np
inp = np.zeros((7,7,3))
for i in range(7):
    for j in range(7):
        inp[i,j,0] = abs(3-i)
        inp[i,j,1] = 0.5*j
inp[6,0,-1]=1
inp[4,1,-1]=1
inp[2,2,-1]=1
inp[0,3,-1]=1
inp[4,2,-1]=1
inp[5,4,-1]=1
inp[6,6,-1]=1
inp[4,3,-1]=-1
inp[5,3,-1]=-1
inp[6,3,-1]=-1
target = np.zeros((3,2))
target[1,0]=1
target[1,1]=-1
target[2,0]=-1
target[2,1]=1
w1 = 0
w2 = 0
b = 0
alpha = 1
error = 1
# while(error != 0):
for o in range(300000):
    print(error)
    error = 0
    for i in range(7):
        for j in range(7):
            summ = ((w1*inp[i,j,0])+(w2*inp[i,j,1])+b)
            if (summ > 0):
                h = 1
            elif (summ < 0):
                h = -1
            else:
                h = 0
            if (inp[i,j,-1] == -1):
                g = 2
            elif (inp[i,j,-1] == 1):
                g = 1
            else:
                g = 0
            if ((h != target[g,0]) and (inp[i,j,-1] != 0)):
                error += 1
            if (h != target[g,0]):
                w1 = w1 + (alpha*inp[i,j,0]*inp[i,j,-1])
                w2 = w2 + (alpha*inp[i,j,1]*inp[i,j,-1])
                b = b +(alpha*inp[i,j,-1])
# print(countzero)
print(w1)
print(w2)
# print(cycle)
print(b)
# Out:
# 1
# 6
# 5
# 4
# 5
# 5
# 7
# 5
# 5
# 6
# 6
# 5
# 6
# 6
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# ...
