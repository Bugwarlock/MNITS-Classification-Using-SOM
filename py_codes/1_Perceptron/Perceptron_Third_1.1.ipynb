# %%
import matplotlib.pyplot as plt
import numpy as np
inp = np.zeros((7,7,3))
for i in range(7):
    for j in range(7):
        inp[i,j,0] = abs(3-i)
        inp[i,j,1] = 0.5*j
inp[6,0,-1]=1
inp[4,1,-1]=1
inp[2,2,-1]=1
inp[0,3,-1]=1
inp[4,2,-1]=1
inp[5,4,-1]=1
inp[6,6,-1]=1
inp[4,3,-1]=-1
inp[5,3,-1]=-1
inp[6,3,-1]=-1
target = np.zeros((3,2))
target[0,0]=-1
target[0,1]=-1
target[1,0]=1
target[1,1]=-1
target[2,0]=-1
target[2,1]=1
w11 = 0
w12 = 0
w21 = 0
w22 = 0
b1 = 0
b2 = 0
alpha = 1
error = 1
# while(error != 0):
for o in range(3000):
    print(error)
    error = 0
    for i in range(7):
        for j in range(7):
            summ1 = ((w11*inp[i,j,0])+(w21*inp[i,j,1])+b1)
            summ2 = ((w12*inp[i,j,0])+(w22*inp[i,j,1])+b2)
            if (summ1 > 0):
                h1 = 1
#             elif (summ1 < 0):
#                 h1 = -1
            else:
                h1 = -1
            if (summ2 > 0):
                h2 = 1
#             elif (summ2 < 0):
#                 h2 = -1
            else:
                h2 = -1
            if (inp[i,j,-1] == -1):
                g = 2
            elif (inp[i,j,-1] == 1):
                g = 1
            else:
                g = 0
            if (((h1 != target[g,0]) and (inp[i,j,-1] != 0) ) or ((h2 != target[g,1]) and (inp[i,j,-1] != 0))):
                error += 1
            if (h1 != target[g,0]):
                w11 = w11 + (alpha*inp[i,j,0]*inp[i,j,-1])
                w21 = w21 + (alpha*inp[i,j,1]*inp[i,j,-1])
                b1 = b1 +(alpha*inp[i,j,-1])
            if (h2 != target[g,1]):
                w12 = w12 + (alpha*inp[i,j,0]*inp[i,j,-1])
                w22 = w22 + (alpha*inp[i,j,1]*inp[i,j,-1])
                b2 = b2 +(alpha*inp[i,j,-1])
# print(countzero)
print(w11)
print(w21)
# print(cycle)
print(b1)
print(w12)
print(w22)
# print(cycle)
print(b2)
# Out:
# 1
# 6
# 5
# 5
# 5
# 5
# 6
# 5
# 5
# 5
# 6
# 6
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# 5
# 7
# 5
# 7
# 6
# ...
